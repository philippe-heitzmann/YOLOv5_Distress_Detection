# %% [markdown]
# <a href="https://colab.research.google.com/github/philippe-heitzmann/Object_Detection/blob/master/Video_Prediction_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img width="1024", src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks

from google.colab import drive
drive.mount('/content/drive')

# %cd ..
# %pwd
# Out:
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.0/78.2 GB disk)
# Mounted at /content/drive
# /content
# '/content'

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/yolov5

# %%
# !cd .. 
# !pwd
# Out:
# /content/yolov5

# %%
# Out:
# /
# '/'

# %%
# !python yolov5/detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source ./drive/MyDrive/videos/potholes_420_500.mp4
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['yolov5s.pt'], source=./drive/MyDrive/videos/potholes_420_500.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-184-g6865d19 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...
# 100% 14.0M/14.0M [00:00<00:00, 160MB/s]
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/1197) /content/drive/MyDrive/videos/potholes_420_500.mp4: 384x640 Done. (0.029s)
# video 1/1 (2/1197) /content/drive/MyDrive/videos/potholes_420_500.mp4: 384x640 Done. (0.029s)
# video 1/1 (3/1197) /content/drive/MyDrive/videos/potholes_420_500.mp4: 384x640 Done. (0.029s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/best.pt --img 640 --conf 0.05 --source ./drive/MyDrive/videos/potholes_420_500.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/best.pt'], source=./drive/MyDrive/videos/potholes_420_500.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-184-g6865d19 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients, 204.0 GFLOPs
# video 1/1 (1/1197) /content/drive/MyDrive/videos/potholes_420_500.mp4: 384x640 Done. (0.153s)
# video 1/1 (2/1197) /content/drive/MyDrive/videos/potholes_420_500.mp4: 384x640 Done. (0.139s)
# video 1/1 (3/1197) /content/drive/MyDrive/videos/potholes_420_500.mp4: 384x640 Done. (0.129s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last_95_640_16_imsc.pt --img 640 --conf 0.05 --source ./drive/MyDrive/videos/potholes_420_500.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last_95_640_16_imsc.pt'], source=./drive/MyDrive/videos/potholes_420_500.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.05, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-184-g6865d19 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 484 layers, 88410801 parameters, 0 gradients
# Traceback (most recent call last):
#   File "yolov5/detect.py", line 257, in <module>
#     main(opt)
#   File "yolov5/detect.py", line 252, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 28, in decorate_context
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --img 640 --conf 0.05 --source ./drive/MyDrive/videos/potholes_420_500.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# ...
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/potholes_420_500.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.05, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-184-g6865d19 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/1197) /content/drive/MyDrive/videos/potholes_420_500.mp4: 384x640 Done. (0.114s)
# video 1/1 (2/1197) /content/drive/MyDrive/videos/potholes_420_500.mp4: 384x640 Done. (0.104s)
# video 1/1 (3/1197) /content/drive/MyDrive/videos/potholes_420_500.mp4: 384x640 Done. (0.093s)
# ...

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %%
# %cd content
# Out:
# /content

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --classes 0 --img 640 --conf 0.05 --source ./drive/MyDrive/videos/ca_driving_longitudinal_crack_trim.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/ca_driving_longitudinal_crack_trim.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.05, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[0], agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/288) /content/drive/MyDrive/videos/ca_driving_longitudinal_crack_trim.mp4: 384x640 Done. (0.110s)
# video 1/1 (2/288) /content/drive/MyDrive/videos/ca_driving_longitudinal_crack_trim.mp4: 384x640 1 Longitudinal Crack, Done. (0.101s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --classes 3 --img 640 --conf 0.10 --source ./drive/MyDrive/videos/ca_driving_longitudinal_alligator_12654_trim2.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/ca_driving_longitudinal_alligator_12654_trim2.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[3], agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/688) /content/drive/MyDrive/videos/ca_driving_longitudinal_alligator_12654_trim2.mp4: 384x640 Done. (0.105s)
# video 1/1 (2/688) /content/drive/MyDrive/videos/ca_driving_longitudinal_alligator_12654_trim2.mp4: 384x640 1 Pothole, Done. (0.096s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --classes 2 --img 640 --conf 0.10 --source ./drive/MyDrive/videos/ca_driving_longitudinal_alligator_12654_trim2.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/ca_driving_longitudinal_alligator_12654_trim2.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[2], agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/688) /content/drive/MyDrive/videos/ca_driving_longitudinal_alligator_12654_trim2.mp4: 384x640 Done. (0.108s)
# video 1/1 (2/688) /content/drive/MyDrive/videos/ca_driving_longitudinal_alligator_12654_trim2.mp4: 384x640 1 Alligator Crack, Done. (0.101s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --classes 1 --img 640 --conf 0.10 --source ./drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# ...
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[1], agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/2030) /content/drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4: 384x640 Done. (0.108s)
# video 1/1 (2/2030) /content/drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4: 384x640 Done. (0.103s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --classes 2 --img 640 --conf 0.10 --source ./drive/MyDrive/videos/ca_driving_alligator_10623_trim1.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/ca_driving_alligator_10623_trim1.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[2], agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/800) /content/drive/MyDrive/videos/ca_driving_alligator_10623_trim1.mp4: 384x640 Done. (0.111s)
# video 1/1 (2/800) /content/drive/MyDrive/videos/ca_driving_alligator_10623_trim1.mp4: 384x640 Done. (0.104s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --classes 1 --img 640 --conf 0.05 --source ./drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.05, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[1], agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/2030) /content/drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4: 384x640 Done. (0.105s)
# video 1/1 (2/2030) /content/drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4: 384x640 Done. (0.095s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --classes 1 --img 640 --conf 0.03 --source ./drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.03, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[1], agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/2030) /content/drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4: 384x640 Done. (0.105s)
# video 1/1 (2/2030) /content/drive/MyDrive/videos/ca_driving_4020_lateral_cracking.mp4: 384x640 Done. (0.096s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --classes 3 --img 640 --conf 0.05 --source ./drive/MyDrive/videos/ca_driving_longitudinal_alligator_12654_trim2.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/ca_driving_longitudinal_alligator_12654_trim2.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.05, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[3], agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/688) /content/drive/MyDrive/videos/ca_driving_longitudinal_alligator_12654_trim2.mp4: 384x640 1 Pothole, Done. (0.105s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --classes 1 --img 640 --conf 0.03 --source ./drive/MyDrive/videos/ca_driving_4020_lateral_trim3.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/ca_driving_4020_lateral_trim3.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.03, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[1], agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/572) /content/drive/MyDrive/videos/ca_driving_4020_lateral_trim3.mp4: 384x640 2 Lateral Cracks, Done. (0.115s)
# video 1/1 (2/572) /content/drive/MyDrive/videos/ca_driving_4020_lateral_trim3.mp4: 384x640 Done. (0.105s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --classes 1 --img 640 --conf 0.03 --source ./drive/MyDrive/videos/ca_driving_lateral_trim4.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/ca_driving_lateral_trim4.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.03, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=[1], agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-187-gf3085ac torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/288) /content/drive/MyDrive/videos/ca_driving_lateral_trim4.mp4: 384x640 2 Lateral Cracks, Done. (0.112s)
# video 1/1 (2/288) /content/drive/MyDrive/videos/ca_driving_lateral_trim4.mp4: 384x640 Done. (0.104s)
# ...

# %%
# !python yolov5/detect.py --weights ./drive/MyDrive/yolo_final_ensemble_weights/last.pt --img 640 --conf 0.05 --source ./drive/MyDrive/videos/ca_driving_15942_20057.mp4 --project ./drive/MyDrive/runs/detect
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600) ./drive/yolo_init_weights/
# Out:
# detect: weights=['./drive/MyDrive/yolo_final_ensemble_weights/last.pt'], source=./drive/MyDrive/videos/ca_driving_15942_20057.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.05, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=./drive/MyDrive/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-186-gb3eaf50 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 367 layers, 46124433 parameters, 0 gradients, 107.8 GFLOPs
# video 1/1 (1/2262) /content/drive/MyDrive/videos/ca_driving_15942_20057.mp4: 384x640 4 Longitudinal Cracks, Done. (0.111s)
# video 1/1 (2/2262) /content/drive/MyDrive/videos/ca_driving_15942_20057.mp4: 384x640 4 Longitudinal Cracks, Done. (0.105s)
# ...

# %%
# data manipulation
import numpy as np
import pandas as pd

#file processing / requests
from pathlib import Path
from tqdm import tqdm
import json
import urllib

#computer vision
import cv2
import torch
import torchvision

import PIL

#ML 
from sklearn.model_selection import train_test_split


#display
from IPython.display import display
from pylab import rcParams

#visualization
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc
import PIL.Image as Image

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
pd.set_option('display.max_columns', None)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.current_device())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# True
# 0
# 1
# NVIDIA GeForce RTX 3090

# %%
nms_thresholds = nms_thresholds[::-1]
nms_thresholds
# Out:
# [0.999, 0.99, 0.95, 0.9, 0.85, 0.8]

# %%
import sys
sys.path.append('/Users/Administrator/DS/IEEE-Big-Data-2020')
sys.path.append('/Users/phil0/DS/IEEE/Object_Detection')
import utils2
from importlib import reload
reload(utils2)
from utils2 import *

nms_thresholds = [0.999, 0.99, 0.95, 0.9, 0.85, 0.8]
conf_thresholds = [0.1, 0.15, 0.2] #, 0.25, 0.3
weights = 'yolov5/runs/train/yolov5x_rdd_32b_0w_1121_3/weights/best.pt yolov5/runs/train/yolov5x_16b_1123_2/weights/best.pt yolov5/runs/train/yolov5x_8b_1124_3/weights/best.pt yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt yolov5/runs/train/yolov5l_rdd_8b_0w_1123_/weights/best.pt'

cmds = get_cmds('test1', 'test2', weights = weights, nms_thresholds = nms_thresholds, conf_thresholds = conf_thresholds, counter = 2, m = 'm2')
for cmd in cmds:
    print(cmd)
    print('------------------------------------')
    
print(len(cmds))
# Out:
#  #pass 1
# !python /Users/phil0/DS/IEEE/yolov5/detect.py --weights yolov5/runs/train/yolov5x_rdd_32b_0w_1121_3/weights/best.pt yolov5/runs/train/yolov5x_16b_1123_2/weights/best.pt yolov5/runs/train/yolov5x_8b_1124_3/weights/best.pt yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt yolov5/runs/train/yolov5l_rdd_8b_0w_1123_/weights/best.pt --img 416 --source ./test1/All_Countries/images --save-txt --save-conf --conf-thres 0.1 --iou-thres 0.999  --agnostic-nms --augment
#
# import sys
# sys.path.append('/Users/Administrator/DS/IEEE-Big-Data-2020')
# sys.path.append('/Users/phil0/DS/IEEE/Object_Detection')
# import utils2
# from importlib import reload
# reload(utils2)
# from utils2 import *
#
# dictdf = get_preds_txt(path = '/Users/phil0/DS/IEEE/yolov5/runs/detect/exp2', confidence=True)
# dictdf.to_csv('results/test1_1.txt', sep = ',', index = False, header = False)
# print('Completed pass 1 on test1')
#
#
# ...

# %%
 #pass 1
# !python /Users/phil0/DS/IEEE/yolov5/detect.py --weights yolov5/runs/train/yolov5x_rdd_32b_0w_1121_3/weights/best.pt yolov5/runs/train/yolov5x_16b_1123_2/weights/best.pt yolov5/runs/train/yolov5x_8b_1124_3/weights/best.pt yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt yolov5/runs/train/yolov5l_rdd_8b_0w_1123_/weights/best.pt --img 416 --source ./test1/All_Countries/images --save-txt --save-conf --conf-thres 0.1 --iou-thres 0.999  --agnostic-nms --augment 

import sys
sys.path.append('/Users/Administrator/DS/IEEE-Big-Data-2020')
sys.path.append('/Users/phil0/DS/IEEE/Object_Detection')
import utils2
from importlib import reload
reload(utils2)
from utils2 import * 

dictdf = get_preds_txt(path = '/Users/phil0/DS/IEEE/yolov5/runs/detect/exp2', confidence=True)
dictdf.to_csv('results/test1_1.txt', sep = ',', index = False, header = False)
print('Completed pass 1 on test1')
# Out:
# detect: weights=['yolov5/runs/train/yolov5x_rdd_32b_0w_1121_3/weights/best.pt', 'yolov5/runs/train/yolov5x_16b_1123_2/weights/best.pt', 'yolov5/runs/train/yolov5x_8b_1124_3/weights/best.pt', 'yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt', 'yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt', 'yolov5/runs/train/yolov5l_rdd_8b_0w_1123_/weights/best.pt'], source=./test1/All_Countries/images, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.999, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=True, augment=True, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2021-10-25 torch 1.10.0a0+3fd9dcf CUDA:0 (NVIDIA GeForce RTX 3090, 24576.0MB)
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients
# Fusing layers...
# ...

# %%
 #pass 2
# !python /Users/phil0/DS/IEEE/yolov5/detect.py --weights yolov5/runs/train/yolov5x_rdd_32b_0w_1121_3/weights/best.pt yolov5/runs/train/yolov5x_16b_1123_2/weights/best.pt yolov5/runs/train/yolov5x_8b_1124_3/weights/best.pt yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt yolov5/runs/train/yolov5l_rdd_8b_0w_1123_/weights/best.pt --img 416 --source ./test2/All_Countries/images --save-txt --save-conf --conf-thres 0.1 --iou-thres 0.999  --agnostic-nms --augment 

import sys
sys.path.append('/Users/Administrator/DS/IEEE-Big-Data-2020')
sys.path.append('/Users/phil0/DS/IEEE/Object_Detection')
import utils2
from importlib import reload
reload(utils2)
from utils2 import * 

dictdf = get_preds_txt(path = '/Users/phil0/DS/IEEE/yolov5/runs/detect/exp2', confidence=True)
dictdf.to_csv('results/test2_2.txt', sep = ',', index = False, header = False)
print('Completed pass 2 on test2')

# %%
------------------------------------
# !python /Users/phil0/DS/IEEE/yolov5/detect.py --weights yolov5/runs/train/yolov5x_rdd_32b_0w_1121_3/weights/best.pt yolov5/runs/train/yolov5x_16b_1123_2/weights/best.pt yolov5/runs/train/yolov5x_8b_1124_3/weights/best.pt yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt yolov5/runs/train/yolov5l_rdd_8b_0w_1123_/weights/best.pt --img 416 --source ./test2/All_Countries/images --save-txt --save-conf --conf-thres 0.1 --iou-thres 0.8  --agnostic-nms --augment 

import sys
sys.path.append('/Users/Administrator/DS/IEEE-Big-Data-2020')
sys.path.append('/Users/phil0/DS/IEEE/Object_Detection')
import utils2
from importlib import reload
reload(utils2)
from utils2 import * 

dictdf = get_preds_txt(path = '/Users/phil0/DS/IEEE/yolov5/runs/detect/exp1', confidence=True)
dictdf.to_csv('results/test2_2.txt', sep = ',', index = False, header = False)
print('Completed pass 2 on test2')

# %%
for cmd in cmds:
    print(cmd)
# Out:
# !python /Users/Administrator/DS/IEEE-Big-Data-2020/yolov5/detect.py --weights yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt --img 416 --source ./test2/All_Countries/images --save-txt --save-conf --conf-thres 0.01 --iou-thres 0.5  --agnostic-nms --augment
# !python /Users/Administrator/DS/IEEE-Big-Data-2020/yolov5/detect.py --weights yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt --img 416 --source ./test2/All_Countries/images --save-txt --save-conf --conf-thres 0.05 --iou-thres 0.5  --agnostic-nms --augment
# !python /Users/Administrator/DS/IEEE-Big-Data-2020/yolov5/detect.py --weights yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt --img 416 --source ./test2/All_Countries/images --save-txt --save-conf --conf-thres 0.1 --iou-thres 0.5  --agnostic-nms --augment
# ...

# %%
--weights yolov5/runs/train/yolov5x_rdd_32b_0w_1121_3/weights/best.pt yolov5/runs/train/yolov5x_16b_1123_2/weights/best.pt yolov5/runs/train/yolov5x_8b_1124_3/weights/best.pt yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt yolov5/runs/train/yolov5l_rdd_8b_0w_1123_/weights/best.pt

# %%
# !python /Users/Administrator/DS/IEEE-Big-Data-2020/yolov5/detect.py --weights yolov5/runs/train/yolov5x_rdd_32b_0w_1121_3/weights/best.pt yolov5/runs/train/yolov5x_16b_1123_2/weights/best.pt yolov5/runs/train/yolov5x_8b_1124_3/weights/best.pt yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt yolov5/runs/train/yolov5l_rdd_8b_0w_1123_/weights/best.pt --img 416 --source ./test2/All_Countries/images --save-txt --save-conf --conf-thres 0.20 --iou-thres 0.9999  --agnostic-nms --augment
# Out:
# ...
# detect: weights=['yolov5/runs/train/yolov5x_rdd_32b_0w_1121_3/weights/best.pt', 'yolov5/runs/train/yolov5x_16b_1123_2/weights/best.pt', 'yolov5/runs/train/yolov5x_8b_1124_3/weights/best.pt', 'yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt', 'yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt', 'yolov5/runs/train/yolov5l_rdd_8b_0w_1123_/weights/best.pt'], source=./test2/All_Countries/images, imgsz=[416, 416], conf_thres=0.2, iou_thres=0.9999, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=True, augment=True, visualize=False, update=False, project=../IEEE-Big-Data-2020/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-35-ga4fece8 torch 1.10.0a0+3fd9dcf CUDA:0 (NVIDIA GeForce RTX 3090, 24575.5MB)
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients
# Fusing layers...
# ...

# %%
#11/25
# !python /Users/phil0/DS/IEEE/yolov5/detect.py --weights yolov5/runs/train/yolov5x_rdd_32b_0w_1121_3/weights/best.pt --img 416 --source ./test2/All_Countries/images --save-txt --save-conf --conf-thres 0.20 --iou-thres 0.9999  --agnostic-nms --augment 

import utils2
from importlib import reload
reload(utils2)
from utils2 import *

dictdf = get_preds_txt(path = '/Users/phil0/DS/IEEE/yolov5/runs/detect/exp', confidence=True) # 'Road-crack-detection/python/DataTest/labels')
dictdf.to_csv('results/test2_1125_m2.txt', sep = ',', index = False, header = False)
# Out:
# detect: weights=['yolov5/runs/train/yolov5x_rdd_32b_0w_1121_3/weights/best.pt'], source=./test2/All_Countries/images, imgsz=[416, 416], conf_thres=0.2, iou_thres=0.9999, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=True, augment=True, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# requirements: /Users/phil0/DS/IEEE/yolov5/requirements.txt not found, check failed.
# YOLOv5 🚀 2021-10-25 torch 1.10.0a0+3fd9dcf CUDA:0 (NVIDIA GeForce RTX 3090, 24576.0MB)
#
# Fusing layers...
# Model Summary: 444 layers, 86193601 parameters, 0 gradients
# image 1/2664 /Users/phil0/DS/IEEE/test2/All_Countries/images/Czech_000003.jpg: 416x416 Done. (0.107s)
# image 2/2664 /Users/phil0/DS/IEEE/test2/All_Countries/images/Czech_000005.jpg: 416x416 48 D00s, Done. (0.101s)
# ...

# %%
number = 9

# eval performs the multiplication passed as argument
square_number = eval('!python --version')
print(square_number)
# Out:
# Traceback (most recent call last):
#
#   File "/opt/conda/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/tmp/ipykernel_79/323246723.py", line 4, in <module>
#     square_number = eval('!python --version')
#
#   File "<string>", line 1
#     !python --version
#     ^
# SyntaxError: invalid syntax

# %%
#11/23
# !python /Users/Administrator/DS/IEEE-Big-Data-2020/yolov5/detect.py --weights yolov5/runs/train/yolov5x_rdd_16b_0w_1121_/weights/best.pt yolov5/runs/train/yolov5l_rdd_32b_0w_1122_2/weights/best.pt --img 416 --source ./test2/All_Countries/images --save-txt --save-conf --conf-thres 0.20 --iou-thres 0.9999  --agnostic-nms --augment
